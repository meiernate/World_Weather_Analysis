# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 740

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]  
        city_current_description = city_weather["weather"][0]["description"]      
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_current_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | longyearbyen
# Processing Record 5 of Set 1 | castro
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | punahana
# Processing Record 8 of Set 1 | saint george
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | alihe
# Processing Record 11 of Set 1 | mar del plata
# Processing Record 12 of Set 1 | kaitangata
# Processing Record 13 of Set 1 | zaterechnyy
# Processing Record 14 of Set 1 | lavrentiya
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | albi
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | east london
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | seltso
# Processing Record 21 of Set 1 | bengkulu
# Processing Record 22 of Set 1 | fortuna
# Processing Record 23 of Set 1 | onda
# Processing Record 24 of Set 1 | geraldton
# Processing Record 25 of Set 1 | meulaboh
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | puerto ayora
# Processing Record 28 of Set 1 | kapaa
# Processing Record 29 of Set 1 | chokurdakh
# Processing Record 30 of Set 1 | tigzirt
# Processing Record 31 of Set 1 | cidreira
# Processing Record 32 of Set 1 | batticaloa
# Processing Record 33 of Set 1 | christchurch
# Processing Record 34 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 1 | cabo san lucas
# Processing Record 36 of Set 1 | nome
# Processing Record 37 of Set 1 | hofn
# Processing Record 38 of Set 1 | kruisfontein
# Processing Record 39 of Set 1 | gao
# Processing Record 40 of Set 1 | ixtapa
# Processing Record 41 of Set 1 | san quintin
# Processing Record 42 of Set 1 | waipawa
# Processing Record 43 of Set 1 | souillac
# Processing Record 44 of Set 1 | hithadhoo
# Processing Record 45 of Set 1 | ciudad bolivar
# Processing Record 46 of Set 1 | clinton
# Processing Record 47 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 48 of Set 1 | mataura
# Processing Record 49 of Set 1 | provideniya
# Processing Record 50 of Set 1 | srandakan
# Processing Record 1 of Set 2 | beringovskiy
# Processing Record 2 of Set 2 | mount isa
# Processing Record 3 of Set 2 | challans
# Processing Record 4 of Set 2 | mahebourg
# Processing Record 5 of Set 2 | aklavik
# Processing Record 6 of Set 2 | cape town
# Processing Record 7 of Set 2 | thompson
# Processing Record 8 of Set 2 | tuktoyaktuk
# Processing Record 9 of Set 2 | phumi samraong
# City not found. Skipping...
# Processing Record 10 of Set 2 | ambovombe
# Processing Record 11 of Set 2 | mount gambier
# Processing Record 12 of Set 2 | avarua
# Processing Record 13 of Set 2 | fort nelson
# Processing Record 14 of Set 2 | kargasok
# Processing Record 15 of Set 2 | lodja
# Processing Record 16 of Set 2 | ushuaia
# Processing Record 17 of Set 2 | herran
# Processing Record 18 of Set 2 | vaini
# Processing Record 19 of Set 2 | atuona
# Processing Record 20 of Set 2 | norman wells
# Processing Record 21 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 2 | labuhan
# Processing Record 23 of Set 2 | baijiantan
# Processing Record 24 of Set 2 | french harbor
# Processing Record 25 of Set 2 | pahrump
# Processing Record 26 of Set 2 | marsh harbour
# Processing Record 27 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 2 | caravelas
# Processing Record 29 of Set 2 | yerbogachen
# Processing Record 30 of Set 2 | barrow
# Processing Record 31 of Set 2 | solano
# Processing Record 32 of Set 2 | pevek
# Processing Record 33 of Set 2 | butaritari
# Processing Record 34 of Set 2 | talnakh
# Processing Record 35 of Set 2 | yithion
# City not found. Skipping...
# Processing Record 36 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 2 | khagaria
# Processing Record 38 of Set 2 | raudeberg
# Processing Record 39 of Set 2 | sao joao da barra
# Processing Record 40 of Set 2 | ribeira grande
# Processing Record 41 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 2 | valparaiso
# Processing Record 43 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 2 | bonavista
# Processing Record 45 of Set 2 | west odessa
# Processing Record 46 of Set 2 | gilgit
# Processing Record 47 of Set 2 | khani
# Processing Record 48 of Set 2 | powell river
# Processing Record 49 of Set 2 | vao
# Processing Record 50 of Set 2 | esil
# Processing Record 1 of Set 3 | dolny kubin
# Processing Record 2 of Set 3 | codrington
# Processing Record 3 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 3 | tiksi
# Processing Record 5 of Set 3 | humboldt
# Processing Record 6 of Set 3 | panjab
# Processing Record 7 of Set 3 | millerovo
# Processing Record 8 of Set 3 | new norfolk
# Processing Record 9 of Set 3 | campo bom
# Processing Record 10 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 3 | port elizabeth
# Processing Record 12 of Set 3 | falealupo
# City not found. Skipping...
# Processing Record 13 of Set 3 | nishihara
# Processing Record 14 of Set 3 | yatou
# Processing Record 15 of Set 3 | luhacovice
# Processing Record 16 of Set 3 | nantucket
# Processing Record 17 of Set 3 | abha
# Processing Record 18 of Set 3 | dikson
# Processing Record 19 of Set 3 | hanyang
# Processing Record 20 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 3 | khasan
# Processing Record 22 of Set 3 | carnarvon
# Processing Record 23 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 3 | esperance
# Processing Record 26 of Set 3 | kalachinsk
# Processing Record 27 of Set 3 | nikolskoye
# Processing Record 28 of Set 3 | trairi
# Processing Record 29 of Set 3 | poum
# Processing Record 30 of Set 3 | broome
# Processing Record 31 of Set 3 | peniche
# Processing Record 32 of Set 3 | barth
# Processing Record 33 of Set 3 | pierre
# Processing Record 34 of Set 3 | bredasdorp
# Processing Record 35 of Set 3 | kulu
# Processing Record 36 of Set 3 | mackenzie
# Processing Record 37 of Set 3 | juneau
# Processing Record 38 of Set 3 | harta
# Processing Record 39 of Set 3 | bowen
# Processing Record 40 of Set 3 | winneba
# Processing Record 41 of Set 3 | dingle
# Processing Record 42 of Set 3 | monrovia
# Processing Record 43 of Set 3 | areia branca
# Processing Record 44 of Set 3 | tasiilaq
# Processing Record 45 of Set 3 | banswada
# Processing Record 46 of Set 3 | saldanha
# Processing Record 47 of Set 3 | wahran
# City not found. Skipping...
# Processing Record 48 of Set 3 | saskylakh
# Processing Record 49 of Set 3 | celestun
# Processing Record 50 of Set 3 | torbay
# Processing Record 1 of Set 4 | tombouctou
# Processing Record 2 of Set 4 | qaanaaq
# Processing Record 3 of Set 4 | albany
# Processing Record 4 of Set 4 | bukachacha
# Processing Record 5 of Set 4 | eskil
# Processing Record 6 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 7 of Set 4 | ostrovnoy
# Processing Record 8 of Set 4 | safwah
# City not found. Skipping...
# Processing Record 9 of Set 4 | oranjestad
# Processing Record 10 of Set 4 | kahului
# Processing Record 11 of Set 4 | sambava
# Processing Record 12 of Set 4 | carauari
# Processing Record 13 of Set 4 | guerrero negro
# Processing Record 14 of Set 4 | dakar
# Processing Record 15 of Set 4 | wasilla
# Processing Record 16 of Set 4 | tepic
# Processing Record 17 of Set 4 | doha
# Processing Record 18 of Set 4 | pitimbu
# Processing Record 19 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 20 of Set 4 | mount pleasant
# Processing Record 21 of Set 4 | abu dhabi
# Processing Record 22 of Set 4 | san cristobal
# Processing Record 23 of Set 4 | karamea
# City not found. Skipping...
# Processing Record 24 of Set 4 | emerald
# Processing Record 25 of Set 4 | pangnirtung
# Processing Record 26 of Set 4 | lata
# Processing Record 27 of Set 4 | sarangani
# Processing Record 28 of Set 4 | shelburne
# Processing Record 29 of Set 4 | kuytun
# Processing Record 30 of Set 4 | uyovu
# Processing Record 31 of Set 4 | itoman
# Processing Record 32 of Set 4 | bambous virieux
# Processing Record 33 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 34 of Set 4 | saint anthony
# Processing Record 35 of Set 4 | ketchikan
# Processing Record 36 of Set 4 | faanui
# Processing Record 37 of Set 4 | boguchany
# Processing Record 38 of Set 4 | yellowknife
# Processing Record 39 of Set 4 | lebu
# Processing Record 40 of Set 4 | puerto escondido
# Processing Record 41 of Set 4 | alofi
# Processing Record 42 of Set 4 | eregli
# Processing Record 43 of Set 4 | broken hill
# Processing Record 44 of Set 4 | bethel
# Processing Record 45 of Set 4 | warrnambool
# Processing Record 46 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 4 | montrose
# Processing Record 48 of Set 4 | foca
# Processing Record 49 of Set 4 | zanzibar
# Processing Record 50 of Set 4 | imeni poliny osipenko
# Processing Record 1 of Set 5 | horasan
# Processing Record 2 of Set 5 | husavik
# Processing Record 3 of Set 5 | erenhot
# Processing Record 4 of Set 5 | payo
# Processing Record 5 of Set 5 | namibe
# Processing Record 6 of Set 5 | bayangol
# Processing Record 7 of Set 5 | rio gallegos
# Processing Record 8 of Set 5 | klaksvik
# Processing Record 9 of Set 5 | cherskiy
# Processing Record 10 of Set 5 | richards bay
# Processing Record 11 of Set 5 | karratha
# Processing Record 12 of Set 5 | atikokan
# Processing Record 13 of Set 5 | saint-francois
# Processing Record 14 of Set 5 | hemet
# Processing Record 15 of Set 5 | nanortalik
# Processing Record 16 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 5 | cayenne
# Processing Record 18 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 5 | svetlogorsk
# Processing Record 20 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 5 | samarai
# Processing Record 22 of Set 5 | jabiru
# City not found. Skipping...
# Processing Record 23 of Set 5 | tual
# Processing Record 24 of Set 5 | lompoc
# Processing Record 25 of Set 5 | la ronge
# Processing Record 26 of Set 5 | san andres
# Processing Record 27 of Set 5 | sola
# Processing Record 28 of Set 5 | victoria
# Processing Record 29 of Set 5 | srednekolymsk
# Processing Record 30 of Set 5 | cuamba
# Processing Record 31 of Set 5 | gogrial
# Processing Record 32 of Set 5 | kongolo
# Processing Record 33 of Set 5 | mbaiki
# Processing Record 34 of Set 5 | chuy
# Processing Record 35 of Set 5 | teguldet
# Processing Record 36 of Set 5 | kodiak
# Processing Record 37 of Set 5 | chara
# Processing Record 38 of Set 5 | berlevag
# Processing Record 39 of Set 5 | kansanshi
# Processing Record 40 of Set 5 | bayji
# Processing Record 41 of Set 5 | shingu
# Processing Record 42 of Set 5 | hunza
# City not found. Skipping...
# Processing Record 43 of Set 5 | havre-saint-pierre
# Processing Record 44 of Set 5 | ahipara
# Processing Record 45 of Set 5 | cururupu
# Processing Record 46 of Set 5 | lagoa
# Processing Record 47 of Set 5 | chardara
# Processing Record 48 of Set 5 | ejea de los caballeros
# Processing Record 49 of Set 5 | lazaro cardenas
# Processing Record 50 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 1 of Set 6 | mandalgovi
# Processing Record 2 of Set 6 | lubango
# Processing Record 3 of Set 6 | alpena
# Processing Record 4 of Set 6 | macamic
# Processing Record 5 of Set 6 | one hundred mile house
# City not found. Skipping...
# Processing Record 6 of Set 6 | rocha
# Processing Record 7 of Set 6 | pimentel
# Processing Record 8 of Set 6 | sinazongwe
# Processing Record 9 of Set 6 | zarubino
# Processing Record 10 of Set 6 | vardo
# Processing Record 11 of Set 6 | saint-philippe
# Processing Record 12 of Set 6 | nuevo progreso
# Processing Record 13 of Set 6 | malanje
# Processing Record 14 of Set 6 | katsiveli
# City not found. Skipping...
# Processing Record 15 of Set 6 | pacific grove
# Processing Record 16 of Set 6 | airai
# Processing Record 17 of Set 6 | sherlovaya gora
# Processing Record 18 of Set 6 | buala
# Processing Record 19 of Set 6 | karasuk
# Processing Record 20 of Set 6 | amapa
# Processing Record 21 of Set 6 | tuatapere
# Processing Record 22 of Set 6 | indianola
# Processing Record 23 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 6 | fairview
# Processing Record 25 of Set 6 | hovd
# Processing Record 26 of Set 6 | narasannapeta
# Processing Record 27 of Set 6 | barranca
# Processing Record 28 of Set 6 | nabire
# Processing Record 29 of Set 6 | arraial do cabo
# Processing Record 30 of Set 6 | kununurra
# Processing Record 31 of Set 6 | banda aceh
# Processing Record 32 of Set 6 | upernavik
# Processing Record 33 of Set 6 | buraydah
# Processing Record 34 of Set 6 | necochea
# Processing Record 35 of Set 6 | cap malheureux
# Processing Record 36 of Set 6 | pishva
# Processing Record 37 of Set 6 | ilulissat
# Processing Record 38 of Set 6 | derzhavinsk
# Processing Record 39 of Set 6 | urumqi
# Processing Record 40 of Set 6 | avera
# Processing Record 41 of Set 6 | tvoroyri
# Processing Record 42 of Set 6 | santa cruz
# Processing Record 43 of Set 6 | zapadnaya dvina
# Processing Record 44 of Set 6 | montemor-o-novo
# Processing Record 45 of Set 6 | huanren
# Processing Record 46 of Set 6 | olafsvik
# Processing Record 47 of Set 6 | fukue
# Processing Record 48 of Set 6 | mao
# Processing Record 49 of Set 6 | ukiah
# Processing Record 50 of Set 6 | mangrol
# Processing Record 1 of Set 7 | taltal
# Processing Record 2 of Set 7 | gurgan
# City not found. Skipping...
# Processing Record 3 of Set 7 | khorixas
# Processing Record 4 of Set 7 | cairns
# Processing Record 5 of Set 7 | acarau
# Processing Record 6 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 7 | mehamn
# Processing Record 8 of Set 7 | gamba
# Processing Record 9 of Set 7 | ionia
# Processing Record 10 of Set 7 | kemijarvi
# Processing Record 11 of Set 7 | sao filipe
# Processing Record 12 of Set 7 | nigde
# Processing Record 13 of Set 7 | neiafu
# Processing Record 14 of Set 7 | san patricio
# Processing Record 15 of Set 7 | dudinka
# Processing Record 16 of Set 7 | chemainus
# Processing Record 17 of Set 7 | les cayes
# Processing Record 18 of Set 7 | san francisco
# Processing Record 19 of Set 7 | nyurba
# Processing Record 20 of Set 7 | tilichiki
# Processing Record 21 of Set 7 | makaryev
# Processing Record 22 of Set 7 | makakilo city
# Processing Record 23 of Set 7 | tinaquillo
# Processing Record 24 of Set 7 | salym
# Processing Record 25 of Set 7 | novi troyany
# Processing Record 26 of Set 7 | walajabad
# City not found. Skipping...
# Processing Record 27 of Set 7 | kudahuvadhoo
# Processing Record 28 of Set 7 | luderitz
# Processing Record 29 of Set 7 | robertsport
# Processing Record 30 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 31 of Set 7 | atocha
# Processing Record 32 of Set 7 | bambanglipuro
# Processing Record 33 of Set 7 | hirara
# Processing Record 34 of Set 7 | flin flon
# Processing Record 35 of Set 7 | jurm
# Processing Record 36 of Set 7 | cartagena
# Processing Record 37 of Set 7 | pathein
# Processing Record 38 of Set 7 | isangel
# Processing Record 39 of Set 7 | port hedland
# Processing Record 40 of Set 7 | duz
# City not found. Skipping...
# Processing Record 41 of Set 7 | santa adelia
# Processing Record 42 of Set 7 | oranjemund
# Processing Record 43 of Set 7 | ponta do sol
# Processing Record 44 of Set 7 | tabas
# Processing Record 45 of Set 7 | kisangani
# Processing Record 46 of Set 7 | sitka
# Processing Record 47 of Set 7 | ambilobe
# Processing Record 48 of Set 7 | georgetown
# Processing Record 49 of Set 7 | pemangkat
# Processing Record 50 of Set 7 | saint-georges
# Processing Record 1 of Set 8 | kassala
# Processing Record 2 of Set 8 | catacamas
# Processing Record 3 of Set 8 | cap-aux-meules
# Processing Record 4 of Set 8 | shahpur
# Processing Record 5 of Set 8 | ghanzi
# Processing Record 6 of Set 8 | leshukonskoye
# Processing Record 7 of Set 8 | hamilton
# Processing Record 8 of Set 8 | nieuw amsterdam
# Processing Record 9 of Set 8 | udachnyy
# Processing Record 10 of Set 8 | gazojak
# Processing Record 11 of Set 8 | khatanga
# Processing Record 12 of Set 8 | lloro
# Processing Record 13 of Set 8 | kavaratti
# Processing Record 14 of Set 8 | les escoumins
# Processing Record 15 of Set 8 | merauke
# Processing Record 16 of Set 8 | abu samrah
# Processing Record 17 of Set 8 | taoudenni
# Processing Record 18 of Set 8 | mitsamiouli
# Processing Record 19 of Set 8 | evensk
# Processing Record 20 of Set 8 | djibo
# Processing Record 21 of Set 8 | riyadh
# Processing Record 22 of Set 8 | talara
# Processing Record 23 of Set 8 | ambon
# Processing Record 24 of Set 8 | santa cruz del sur
# Processing Record 25 of Set 8 | kawalu
# Processing Record 26 of Set 8 | monster
# Processing Record 27 of Set 8 | eenhana
# Processing Record 28 of Set 8 | xining
# Processing Record 29 of Set 8 | naze
# Processing Record 30 of Set 8 | maumere
# Processing Record 31 of Set 8 | chicago
# Processing Record 32 of Set 8 | borovskoy
# Processing Record 33 of Set 8 | megion
# Processing Record 34 of Set 8 | taquari
# Processing Record 35 of Set 8 | narsaq
# Processing Record 36 of Set 8 | barinitas
# Processing Record 37 of Set 8 | sao felix do xingu
# Processing Record 38 of Set 8 | comodoro rivadavia
# Processing Record 39 of Set 8 | half moon bay
# Processing Record 40 of Set 8 | kailua
# Processing Record 41 of Set 8 | petrolina de goias
# Processing Record 42 of Set 8 | kaset sombun
# Processing Record 43 of Set 8 | takoradi
# Processing Record 44 of Set 8 | havoysund
# Processing Record 45 of Set 8 | clyde river
# Processing Record 46 of Set 8 | krasnyy chikoy
# Processing Record 47 of Set 8 | sulangan
# Processing Record 48 of Set 8 | chadan
# Processing Record 49 of Set 8 | college
# Processing Record 50 of Set 8 | manta
# Processing Record 1 of Set 9 | adamovka
# Processing Record 2 of Set 9 | borogontsy
# Processing Record 3 of Set 9 | kamenka
# Processing Record 4 of Set 9 | walvis bay
# Processing Record 5 of Set 9 | batemans bay
# Processing Record 6 of Set 9 | fairbanks
# Processing Record 7 of Set 9 | rizoma
# Processing Record 8 of Set 9 | ouargaye
# Processing Record 9 of Set 9 | solnechnyy
# Processing Record 10 of Set 9 | moerai
# Processing Record 11 of Set 9 | ambunti
# Processing Record 12 of Set 9 | katsuura
# Processing Record 13 of Set 9 | segovia
# Processing Record 14 of Set 9 | nkoyaphiri
# Processing Record 15 of Set 9 | hasaki
# Processing Record 16 of Set 9 | ningxiang
# Processing Record 17 of Set 9 | ranong
# Processing Record 18 of Set 9 | abbeyleix
# Processing Record 19 of Set 9 | prado
# Processing Record 20 of Set 9 | topeka
# Processing Record 21 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 22 of Set 9 | lakes entrance
# Processing Record 23 of Set 9 | northam
# Processing Record 24 of Set 9 | constitucion
# Processing Record 25 of Set 9 | zaraysk
# Processing Record 26 of Set 9 | nioro
# Processing Record 27 of Set 9 | santa maria
# Processing Record 28 of Set 9 | bar harbor
# Processing Record 29 of Set 9 | la reforma
# Processing Record 30 of Set 9 | praia da vitoria
# Processing Record 31 of Set 9 | manama
# Processing Record 32 of Set 9 | sal rei
# Processing Record 33 of Set 9 | mgandu
# Processing Record 34 of Set 9 | tabou
# Processing Record 35 of Set 9 | aksu
# Processing Record 36 of Set 9 | noumea
# Processing Record 37 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 38 of Set 9 | coolum beach
# Processing Record 39 of Set 9 | buenos aires
# Processing Record 40 of Set 9 | dubrovka
# Processing Record 41 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 42 of Set 9 | jimma
# Processing Record 43 of Set 9 | road town
# Processing Record 44 of Set 9 | mugur-aksy
# Processing Record 45 of Set 9 | guilin
# Processing Record 46 of Set 9 | gizo
# Processing Record 47 of Set 9 | menongue
# Processing Record 48 of Set 9 | adzope
# Processing Record 49 of Set 9 | xichang
# Processing Record 50 of Set 9 | kilindoni
# Processing Record 1 of Set 10 | san juan
# Processing Record 2 of Set 10 | saint-germain-de-grantham
# Processing Record 3 of Set 10 | mackay
# Processing Record 4 of Set 10 | shache
# Processing Record 5 of Set 10 | muncar
# Processing Record 6 of Set 10 | shimoda
# Processing Record 7 of Set 10 | masuguru
# Processing Record 8 of Set 10 | gardez
# Processing Record 9 of Set 10 | zachagansk
# City not found. Skipping...
# Processing Record 10 of Set 10 | gold coast
# Processing Record 11 of Set 10 | namasuba
# Processing Record 12 of Set 10 | sinop
# Processing Record 13 of Set 10 | salalah
# Processing Record 14 of Set 10 | jaguey grande
# Processing Record 15 of Set 10 | sa kaeo
# Processing Record 16 of Set 10 | xian
# Processing Record 17 of Set 10 | hot springs
# Processing Record 18 of Set 10 | ewa beach
# Processing Record 19 of Set 10 | mayo
# Processing Record 20 of Set 10 | bandarbeyla
# Processing Record 21 of Set 10 | ranfurly
# Processing Record 22 of Set 10 | aosta
# Processing Record 23 of Set 10 | dehloran
# Processing Record 24 of Set 10 | namatanai
# Processing Record 25 of Set 10 | hami
# Processing Record 26 of Set 10 | alanya
# Processing Record 27 of Set 10 | port hardy
# Processing Record 28 of Set 10 | batagay
# Processing Record 29 of Set 10 | kifri
# Processing Record 30 of Set 10 | port-gentil
# Processing Record 31 of Set 10 | iqaluit
# Processing Record 32 of Set 10 | basco
# Processing Record 33 of Set 10 | jiquipilas
# Processing Record 34 of Set 10 | roquetas de mar
# Processing Record 35 of Set 10 | jaypur
# Processing Record 36 of Set 10 | marsaxlokk
# Processing Record 37 of Set 10 | dir
# Processing Record 38 of Set 10 | yunjinghong
# City not found. Skipping...
# Processing Record 39 of Set 10 | manaus
# Processing Record 40 of Set 10 | matara
# Processing Record 41 of Set 10 | riyaq
# City not found. Skipping...
# Processing Record 42 of Set 10 | impfondo
# Processing Record 43 of Set 10 | batagay-alyta
# Processing Record 44 of Set 10 | bereda
# Processing Record 45 of Set 10 | alabaster
# Processing Record 46 of Set 10 | sorland
# Processing Record 47 of Set 10 | tecoanapa
# Processing Record 48 of Set 10 | tambacounda
# Processing Record 49 of Set 10 | aquiraz
# Processing Record 50 of Set 10 | vila franca do campo
# Processing Record 1 of Set 11 | gardner
# Processing Record 2 of Set 11 | san ignacio
# Processing Record 3 of Set 11 | chapleau
# Processing Record 4 of Set 11 | camacha
# Processing Record 5 of Set 11 | iwata
# Processing Record 6 of Set 11 | at-bashi
# Processing Record 7 of Set 11 | uithoorn
# Processing Record 8 of Set 11 | san luis
# Processing Record 9 of Set 11 | dargaville
# Processing Record 10 of Set 11 | omboue
# Processing Record 11 of Set 11 | pisco
# Processing Record 12 of Set 11 | mujiayingzi
# Processing Record 13 of Set 11 | san policarpo
# Processing Record 14 of Set 11 | parabel
# Processing Record 15 of Set 11 | bilibino
# Processing Record 16 of Set 11 | la asuncion
# Processing Record 17 of Set 11 | green river
# Processing Record 18 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 19 of Set 11 | chanute
# Processing Record 20 of Set 11 | komsomolskiy
# Processing Record 21 of Set 11 | isiro
# Processing Record 22 of Set 11 | sumbawa
# City not found. Skipping...
# Processing Record 23 of Set 11 | tarhunah
# City not found. Skipping...
# Processing Record 24 of Set 11 | santander jimenez
# Processing Record 25 of Set 11 | puri
# Processing Record 26 of Set 11 | matagami
# Processing Record 27 of Set 11 | kidal
# Processing Record 28 of Set 11 | puerto el triunfo
# Processing Record 29 of Set 11 | riviere-au-renard
# Processing Record 30 of Set 11 | ujiie
# Processing Record 31 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 32 of Set 11 | toronto
# Processing Record 33 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 11 | eyl
# Processing Record 35 of Set 11 | gorno-altaysk
# Processing Record 36 of Set 11 | muisne
# Processing Record 37 of Set 11 | chimbote
# Processing Record 38 of Set 11 | aykhal
# Processing Record 39 of Set 11 | severnyy
# Processing Record 40 of Set 11 | goundam
# Processing Record 41 of Set 11 | pangai
# Processing Record 42 of Set 11 | barra do corda
# Processing Record 43 of Set 11 | ponta delgada
# Processing Record 44 of Set 11 | tygda
# Processing Record 45 of Set 11 | zeya
# Processing Record 46 of Set 11 | santona
# Processing Record 47 of Set 11 | haverfordwest
# Processing Record 48 of Set 11 | hervey bay
# Processing Record 49 of Set 11 | ploemeur
# Processing Record 50 of Set 11 | haapiti
# Processing Record 1 of Set 12 | pringsewu
# Processing Record 2 of Set 12 | khash
# Processing Record 3 of Set 12 | los llanos de aridane
# Processing Record 4 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 12 | tarimoro
# Processing Record 6 of Set 12 | boffa
# Processing Record 7 of Set 12 | dhidhdhoo
# Processing Record 8 of Set 12 | wilmington
# Processing Record 9 of Set 12 | balkanabat
# Processing Record 10 of Set 12 | rehoboth
# Processing Record 11 of Set 12 | mersing
# Processing Record 12 of Set 12 | idar
# Processing Record 13 of Set 12 | uaua
# Processing Record 14 of Set 12 | tecolutilla
# Processing Record 15 of Set 12 | podor
# Processing Record 16 of Set 12 | marquette
# Processing Record 17 of Set 12 | manicore
# Processing Record 18 of Set 12 | baruun-urt
# Processing Record 19 of Set 12 | susurluk
# Processing Record 20 of Set 12 | lorengau
# Processing Record 21 of Set 12 | zyryanka
# Processing Record 22 of Set 12 | uvalde
# Processing Record 23 of Set 12 | marfino
# Processing Record 24 of Set 12 | bentiu
# Processing Record 25 of Set 12 | lyskovo
# Processing Record 26 of Set 12 | rodniki
# Processing Record 27 of Set 12 | hauge
# Processing Record 28 of Set 12 | camopi
# Processing Record 29 of Set 12 | aasiaat
# Processing Record 30 of Set 12 | muborak
# Processing Record 31 of Set 12 | olinda
# Processing Record 32 of Set 12 | west wendover
# Processing Record 33 of Set 12 | milton
# Processing Record 34 of Set 12 | laguna
# Processing Record 35 of Set 12 | san carlos de bariloche
# Processing Record 36 of Set 12 | mogadishu
# Processing Record 37 of Set 12 | vanderhoof
# Processing Record 38 of Set 12 | vikhorevka
# Processing Record 39 of Set 12 | sao gabriel da cachoeira
# Processing Record 40 of Set 12 | ajdabiya
# Processing Record 41 of Set 12 | akdepe
# Processing Record 42 of Set 12 | port macquarie
# Processing Record 43 of Set 12 | warsaw
# Processing Record 44 of Set 12 | huarmey
# Processing Record 45 of Set 12 | suixi
# Processing Record 46 of Set 12 | vanavara
# Processing Record 47 of Set 12 | panzhihua
# Processing Record 48 of Set 12 | sabang
# Processing Record 49 of Set 12 | lagunas
# Processing Record 50 of Set 12 | gutierrez
# Processing Record 1 of Set 13 | adrar
# Processing Record 2 of Set 13 | joshimath
# Processing Record 3 of Set 13 | bedele
# Processing Record 4 of Set 13 | jos
# Processing Record 5 of Set 13 | raton
# Processing Record 6 of Set 13 | quatre cocos
# Processing Record 7 of Set 13 | kavieng
# Processing Record 8 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 9 of Set 13 | novoagansk
# Processing Record 10 of Set 13 | azangaro
# Processing Record 11 of Set 13 | porbandar
# Processing Record 12 of Set 13 | sokoto
# Processing Record 13 of Set 13 | vilyuysk
# Processing Record 14 of Set 13 | atambua
# Processing Record 15 of Set 13 | birjand
# Processing Record 16 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 17 of Set 13 | naifaru
# Processing Record 18 of Set 13 | jacksonville
# Processing Record 19 of Set 13 | jaisalmer
# Processing Record 20 of Set 13 | lermontovka
# Processing Record 21 of Set 13 | novoyegoryevskoye
# City not found. Skipping...
# Processing Record 22 of Set 13 | sabla
# Processing Record 23 of Set 13 | male
# Processing Record 24 of Set 13 | itacoatiara
# Processing Record 25 of Set 13 | kieta
# Processing Record 26 of Set 13 | hualmay
# Processing Record 27 of Set 13 | lawan kuda baharu
# City not found. Skipping...
# Processing Record 28 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 13 | castanos
# Processing Record 30 of Set 13 | nenjiang
# Processing Record 31 of Set 13 | yumen
# Processing Record 32 of Set 13 | springfield
# Processing Record 33 of Set 13 | chiquilistlan
# Processing Record 34 of Set 13 | barabai
# Processing Record 35 of Set 13 | ancud
# Processing Record 36 of Set 13 | lieksa
# Processing Record 37 of Set 13 | skelleftea
# Processing Record 38 of Set 13 | konstantinovka
# Processing Record 39 of Set 13 | guarda
# Processing Record 40 of Set 13 | high level
# Processing Record 41 of Set 13 | timmins
# Processing Record 42 of Set 13 | faya
# Processing Record 43 of Set 13 | san matias
# Processing Record 44 of Set 13 | hay river
# Processing Record 45 of Set 13 | port jervis
# Processing Record 46 of Set 13 | dunedin
# Processing Record 47 of Set 13 | belle fourche
# Processing Record 48 of Set 13 | hoquiam
# Processing Record 49 of Set 13 | pangkalanbuun
# Processing Record 50 of Set 13 | lokosovo
# Processing Record 1 of Set 14 | yulara
# Processing Record 2 of Set 14 | wajir
# Processing Record 3 of Set 14 | sura
# Processing Record 4 of Set 14 | innisfail
# Processing Record 5 of Set 14 | hambantota
# Processing Record 6 of Set 14 | muleba
# Processing Record 7 of Set 14 | port lincoln
# Processing Record 8 of Set 14 | calabozo
# Processing Record 9 of Set 14 | mankono
# Processing Record 10 of Set 14 | mathathane
# Processing Record 11 of Set 14 | sovetskiy
# Processing Record 12 of Set 14 | ust-ishim
# Processing Record 13 of Set 14 | aksarka
# Processing Record 14 of Set 14 | chihuahua
# Processing Record 15 of Set 14 | coihaique
# Processing Record 16 of Set 14 | goderich
# Processing Record 17 of Set 14 | anisoc
# Processing Record 18 of Set 14 | maua
# Processing Record 19 of Set 14 | jasper
# Processing Record 20 of Set 14 | pasni
# Processing Record 21 of Set 14 | shagonar
# Processing Record 22 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 23 of Set 14 | dukat
# Processing Record 24 of Set 14 | padang
# Processing Record 25 of Set 14 | nur
# Processing Record 26 of Set 14 | guhagar
# Processing Record 27 of Set 14 | senneterre
# Processing Record 28 of Set 14 | oum hadjer
# Processing Record 29 of Set 14 | praia
# Processing Record 30 of Set 14 | afmadu
# City not found. Skipping...
# Processing Record 31 of Set 14 | kirakira
# Processing Record 32 of Set 14 | russkiy
# Processing Record 33 of Set 14 | guane
# Processing Record 34 of Set 14 | kudinovo
# Processing Record 35 of Set 14 | larsnes
# Processing Record 36 of Set 14 | flinders
# Processing Record 37 of Set 14 | sioux lookout
# Processing Record 38 of Set 14 | springdale
# Processing Record 39 of Set 14 | mahadday weyne
# City not found. Skipping...
# Processing Record 40 of Set 14 | kodinsk
# Processing Record 41 of Set 14 | panaba
# Processing Record 42 of Set 14 | saran
# Processing Record 43 of Set 14 | hluti
# Processing Record 44 of Set 14 | tura
# Processing Record 45 of Set 14 | zhangjiakou
# Processing Record 46 of Set 14 | maragogi
# Processing Record 47 of Set 14 | gambissara
# Processing Record 48 of Set 14 | alugan
# Processing Record 49 of Set 14 | traverse city
# Processing Record 50 of Set 14 | palmer
# Processing Record 1 of Set 15 | sangar
# Processing Record 2 of Set 15 | donegal
# Processing Record 3 of Set 15 | coquimbo
# Processing Record 4 of Set 15 | abancay
# Processing Record 5 of Set 15 | malinovoye ozero
# Processing Record 6 of Set 15 | bud
# Processing Record 7 of Set 15 | port blair
# Processing Record 8 of Set 15 | salinas
# Processing Record 9 of Set 15 | bitung
# Processing Record 10 of Set 15 | dandong
# Processing Record 11 of Set 15 | safford
# Processing Record 12 of Set 15 | fare
# Processing Record 13 of Set 15 | bulembu
# Processing Record 14 of Set 15 | sergeyevka
# Processing Record 15 of Set 15 | antanifotsy
# Processing Record 16 of Set 15 | camana
# Processing Record 17 of Set 15 | saint-leu
# Processing Record 18 of Set 15 | farafangana
# Processing Record 19 of Set 15 | ust-nera
# Processing Record 20 of Set 15 | ornskoldsvik
# Processing Record 21 of Set 15 | iznik
# Processing Record 22 of Set 15 | gafanha da encarnacao
# Processing Record 23 of Set 15 | palana
# Processing Record 24 of Set 15 | nea alikarnassos
# Processing Record 25 of Set 15 | calama
# Processing Record 26 of Set 15 | miri
# Processing Record 27 of Set 15 | ouesso
# Processing Record 28 of Set 15 | wanxian
# Processing Record 29 of Set 15 | bossangoa
# Processing Record 30 of Set 15 | henzada
# City not found. Skipping...
# Processing Record 31 of Set 15 | san rafael del sur
# Processing Record 32 of Set 15 | ziway
# Processing Record 33 of Set 15 | hobyo
# Processing Record 34 of Set 15 | lakselv
# Processing Record 35 of Set 15 | leningradskiy
# Processing Record 36 of Set 15 | dongying
# Processing Record 37 of Set 15 | bathsheba
# Processing Record 38 of Set 15 | chapais
# Processing Record 39 of Set 15 | kochki
# Processing Record 40 of Set 15 | roma
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 684

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Port Alfred -33.5906   26.8910     58.17        91          97
# 1     Busselton -33.6500  115.3333     55.81        73          93
# 2  Punta Arenas -53.1500  -70.9167     51.91        62           0
# 3  Longyearbyen  78.2186   15.6401     39.04        70          75
# 4        Castro -24.7911  -50.0119     60.62        77           0
# 5      Hermanus -34.4187   19.2345     51.80        69           2
# 6      Punahana  27.8667   77.2000     79.93        60          29
# 7  Saint George  37.1041 -113.5841     87.44        25           0
# 8       Rikitea -23.1203 -134.9692     69.71        64          68
# 9         Alihe  50.5667  123.7167     23.34        53          49
#
#    Wind Speed Country Current Description
# 0       14.52      ZA     overcast clouds
# 1       13.38      AU     overcast clouds
# 2       16.11      CL           clear sky
# 3        8.05      SJ       broken clouds
# 4        0.54      BR           clear sky
# 5        0.38      ZA           clear sky
# 6        5.06      IN    scattered clouds
# 7        3.00      US           clear sky
# 8       24.27      PF       broken clouds
# 9        3.62      CN    scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Port Alfred      ZA -33.5906   26.8910     58.17        91          97
# 1     Busselton      AU -33.6500  115.3333     55.81        73          93
# 2  Punta Arenas      CL -53.1500  -70.9167     51.91        62           0
# 3  Longyearbyen      SJ  78.2186   15.6401     39.04        70          75
# 4        Castro      BR -24.7911  -50.0119     60.62        77           0
# 5      Hermanus      ZA -34.4187   19.2345     51.80        69           2
# 6      Punahana      IN  27.8667   77.2000     79.93        60          29
# 7  Saint George      US  37.1041 -113.5841     87.44        25           0
# 8       Rikitea      PF -23.1203 -134.9692     69.71        64          68
# 9         Alihe      CN  50.5667  123.7167     23.34        53          49
#
#    Wind Speed Current Description
# 0       14.52     overcast clouds
# 1       13.38     overcast clouds
# 2       16.11           clear sky
# 3        8.05       broken clouds
# 4        0.54           clear sky
# 5        0.38           clear sky
# 6        5.06    scattered clouds
# 7        3.00           clear sky
# 8       24.27       broken clouds
# 9        3.62    scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
